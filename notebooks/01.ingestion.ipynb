# %%
import feedparser, os, re
import sqlite3

# %%
RSS_FEEDS = [
    "https://www.marketbeat.com/feed/", 
    "https://economictimes.indiatimes.com/markets/rssfeeds/1977021501.cms", 
    "https://www.etnownews.com/feeds/gns-etn-companies.xml", 
    "https://www.cnbctv18.com/commonfeeds/v1/cne/rss/business.xml", 
    #"https://www.financeasia.com/rss/latest"
]

# %%
parsed = feedparser.parse(RSS_FEEDS[2])
parsed.entries[0]
# Out:
# {'id': '153230811',
#  'guidislink': False,
#  'published': 'Mon, 01 Dec 2025 16:16:28 +0530',
#  'published_parsed': time.struct_time(tm_year=2025, tm_mon=12, tm_mday=1, tm_hour=10, tm_min=46, tm_sec=28, tm_wday=0, tm_yday=335, tm_isdst=0),
#  'title': 'PAG emerging as lead bidder to acquire tech firm Accion Labs',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://www.etnownews.com/feeds/gns-etn-companies.xml',
#   'value': 'PAG emerging as lead bidder to acquire tech firm Accion Labs'},
#  'summary': 'Pittsburg, PA United States based Accion Labs was founded in 2011 by Kinesh Doshi. The firm employs more than 4,400 people across 23 locations globally, according to its website.',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://www.etnownews.com/feeds/gns-etn-companies.xml',
#   'value': 'Pittsburg, PA United States based Accion Labs was founded in 2011 by Kinesh Doshi. The firm employs more than 4,400 people across 23 locations globally, according to its website.'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://www.etnownews.com/companies/pag-emerging-as-lead-bidder-to-acquire-tech-firm-accion-labs-article-153230811'}],
#  'link': 'https://www.etnownews.com/companies/pag-emerging-as-lead-bidder-to-acquire-tech-firm-accion-labs-article-153230811',
#  'content': [{'type': 'text/html',
#    'language': None,
#    'base': 'https://www.etnownews.com/feeds/gns-etn-companies.xml',
#    'value': '<div><img alt="pag emerging as lead bidder to acquire tech firm accion labs" class="type:primaryImage" src="https://images.etnownews.com/thumb/msid-153230811,imgsize-20522,width-1280,height-720/153230811.jpg" /></div><p>Asia focused investor PAG is emerging the frontrunner for acquiring a majority equity stake in digital and cloud services engineering firm Accion Labs, people familiar with the matter said.</p><p>PAG, which has put a binding bid for the deal, is seeking to buy shareholdings of peer private equity investors TA Associates and True North in Accion Labs, the people said. PAG’s valuation of Accion Labs is said to be in the range of $800 million to $1 billion, they added.</p><p>Pittsburg, PA United States based Accion Labs was founded in 2011 by Kinesh Doshi. The firm employs more than 4,400 people across 23 locations globally, according to its website.</p><p>Etisalat, a key telecom operator of United Arab Emirates, is also evaluating acquisition of a controlling equity holding from TA and True North in Accion Labs. Certain global PE investors have also sought to acquire the stakes of both shareholders in the company, the people said.</p><p>PAG declined to comment on the matter. Accion CEO Kinesh Doshi, TA Associates and True North didn’t reply to separate ET NOW emailed queries. An attempt to reach the Dubai-based communications representative of Etisalat went unanswered.</p><p>TA Associates first invested in Accion Labs in 2020, followed by a second equity financing round in 2023. Indium VI (Mauritius) Holdings, advised by True North, acquired a “significant minority stake” in Accion in 2022. The firm completed Series C funding from an investor group, including Allcargo Logistics in March 2024, according to startup data platform Tracxn.</p><p>PAG’s investments in India include ownership in money manager Nuvama Wealth Management and Optimus Drugs, according to the investor’s website.</p><p>  <div title="Custom" type="javascript"><blockquote class="twitter-tweet"><p dir="ltr" lang="en"><a href="https://twitter.com/hashtag/Exclusive?src=hash&amp;ref_src=twsrc%5Etfw">#Exclusive</a> | Asia-focused PE giant PAG is emerging as the frontrunner to snap up a majority stake in digital engineering firm Accion Labs, <a href="https://twitter.com/hashtag/sources?src=hash&amp;ref_src=twsrc%5Etfw">#sources</a> tell <a href="https://twitter.com/hashtag/ETNOW?src=hash&amp;ref_src=twsrc%5Etfw">#ETNOW</a>.<br /><br />Anurag Joshi has the inside track👇<a href="https://twitter.com/anujosh_aj?ref_src=twsrc%5Etfw">@anujosh_aj</a> <a href="https://twitter.com/hashtag/AccionLabs?src=hash&amp;ref_src=twsrc%5Etfw">#AccionLabs</a> <a href="https://twitter.com/hashtag/PAG?src=hash&amp;ref_src=twsrc%5Etfw">#PAG</a> <a href="https://twitter.com/hashtag/StockMarket?src=hash&amp;ref_src=twsrc%5Etfw">#StockMarket</a> <a href="https://t.co/bj9JtBMrwS">https://t.co/bj9JtBMrwS</a> <a href="https://t.co/0y8kCaG9BU">pic.twitter.com/0y8kCaG9BU</a></p>&mdash; ET NOW (@ETNOWlive) <a href="https://twitter.com/ETNOWlive/status/1995398013993525744?ref_src=twsrc%5Etfw">December 1, 2025</a></blockquote> </div></p><p>PAG’s plans to offload its about 54% holding in Nuvama is currently on hold, amid Nuvama’s business relationships with U.S. quant investor Jane Street, that faces allegations of market manipulation in a July interim order of Securities and Exchange Board of India.</p><p>“Global digital product engineering services market was valued at $2.24 billion in 2024 and is projected to reach $3.12 billion by 2032,” Intel Market Research said in a report, earlier this year. “Market growth is primarily driven by increasing digital transformation initiatives across enterprises, with particular momentum in North America where the U.S. accounted for the largest regional share.”</p>'}],
#  'authors': [{'name': 'Anurag Joshi'}],
#  'author': 'Anurag Joshi',
#  'author_detail': {'name': 'Anurag Joshi'}}

# %%
def fetch_rss_feeds():
    articles = []
    for feed in RSS_FEEDS:
        parsed = feedparser.parse(feed)
        for entry in parsed.entries:
            articles.append({
                "source": feed,
                "url": entry.link,
                "title": entry.title,
                "content": entry.summary,
                "published_at": getattr(entry, "published", None)
            })
    print("Fetching News was successful!")
    return articles

articles = fetch_rss_feeds()
print(f"---\nTotal articles fetched: {len(articles)}")
articles[23]
# Out:
# Fetching News was successful!
# ---
# Total articles fetched: 400
# {'source': 'https://www.marketbeat.com/feed/',
#  'url': 'https://www.marketbeat.com/stock-ideas/these-2-energy-titans-just-scored-major-wins-to-close-out-november/',
#  'title': 'These 2 Energy Titans Just Scored Major Wins to Close Out November',
#  'content': 'Constellation Energy and GE Vernova are two AI enablers that have soared in 2025. The companies received more positive news in November.',
#  'published_at': 'Wed, 26 Nov 2025 13:21:00 GMT'}

# %%
def clean_text(text):
    text = re.sub(r"\s+", " ", text)
    text = text.strip()
    return text

def standardize_article(a):
    return {
        "source": a["source"],
        "url": a["url"],
        "title": clean_text(a["title"]),
        "content": clean_text(a["content"]),
        "published_at": a["published_at"]
    }

standardized_articles = [standardize_article(a) for a in articles]
print("All articles have been standardized")
standardized_articles[23]
# Out:
# All articles have been standardized
# {'source': 'https://www.marketbeat.com/feed/',
#  'url': 'https://www.marketbeat.com/stock-ideas/these-2-energy-titans-just-scored-major-wins-to-close-out-november/',
#  'title': 'These 2 Energy Titans Just Scored Major Wins to Close Out November',
#  'content': 'Constellation Energy and GE Vernova are two AI enablers that have soared in 2025. The companies received more positive news in November.',
#  'published_at': 'Wed, 26 Nov 2025 13:21:00 GMT'}

# %%
os.makedirs("../data", exist_ok=True)

conn = sqlite3.connect("../data/financial_news.db")
print("Connected!")

cur = conn.cursor()
cur.execute("""
CREATE TABLE IF NOT EXISTS raw_news (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            source TEXT,
            url TEXT,
            title TEXT,
            content TEXT,
            published_at TEXT
            )
""")

conn.commit()
cur.close()
conn.close()
# Out:
# Connected!

# %%
def save_articles_to_db(article):
    conn = sqlite3.connect("../data/financial_news.db")
    cur = conn.cursor()

    cur.execute("""
        INSERT INTO raw_news (source, url, title, content, published_at)
        VALUES ( ?, ?, ?, ?, ?)
        """, (
            article["source"],
            article["url"],
            article["title"],
            article["content"],
            article["published_at"]
        ))
    
    conn.commit()
    cur.close()
    conn.close()

for article in standardized_articles:
    save_articles_to_db(article)

print("All articles saved to db.")
# Out:
# All articles saved to db.
