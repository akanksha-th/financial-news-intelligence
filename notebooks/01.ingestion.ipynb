# %%
import feedparser, os, re
import sqlite3

# %%
RSS_FEEDS = [
    "https://www.marketbeat.com/feed/", 
    "https://economictimes.indiatimes.com/markets/rssfeeds/1977021501.cms", 
    "https://www.etnownews.com/feeds/gns-etn-companies.xml", 
    "https://www.cnbctv18.com/commonfeeds/v1/cne/rss/business.xml", 
    #"https://www.financeasia.com/rss/latest"
]

# %%
parsed = feedparser.parse(RSS_FEEDS[2])
parsed.entries[0]
# Out:
# {'id': '153220552',
#  'guidislink': False,
#  'published': 'Sat, 29 Nov 2025 08:58:56 +0530',
#  'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=29, tm_hour=3, tm_min=28, tm_sec=56, tm_wday=5, tm_yday=333, tm_isdst=0),
#  'title': 'Bandhan Bank NPA sale of Rs 7000 crore approved by board',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://www.etnownews.com/feeds/gns-etn-companies.xml',
#   'value': 'Bandhan Bank NPA sale of Rs 7000 crore approved by board'},
#  'summary': "Bandhan Bank NPA sale: Bandhan Bank plans to sell NPAs and written-off loans worth Rs 6,931.31 crore using the Swiss Challenge and auctions. Share's long-term returns remain poor.",
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://www.etnownews.com/feeds/gns-etn-companies.xml',
#   'value': "Bandhan Bank NPA sale: Bandhan Bank plans to sell NPAs and written-off loans worth Rs 6,931.31 crore using the Swiss Challenge and auctions. Share's long-term returns remain poor."},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://www.etnownews.com/companies/bandhan-bank-npa-sale-of-rs-7000-crore-approved-by-board-article-153220552'}],
#  'link': 'https://www.etnownews.com/companies/bandhan-bank-npa-sale-of-rs-7000-crore-approved-by-board-article-153220552',
#  'content': [{'type': 'text/html',
#    'language': None,
#    'base': 'https://www.etnownews.com/feeds/gns-etn-companies.xml',
#    'value': '<div><img alt="bandhan bank npa sale of rs 7000 crore approved by board" class="type:primaryImage" src="https://images.etnownews.com/thumb/msid-153220552,imgsize-712300,width-1280,height-720/153220552.jpg" /></div><p><strong>Bandhan Bank NPA sale</strong>: Bandhan Bank Limited announced that its Board of Directors has approved the sale of identified non-performing assets (NPAs) and written-off loan portfolios, amounting to a combined Rs 6,931.31 crore, through a structured bidding process.</p><p>The decision was taken at the Board meeting held on Thursday, November 27, 2025, the company informed in an exchange filing.</p><p>Additionally, the bank will adopt the Swiss Challenge method for the sale of NPAs with more than 180 days past due, which carry a principal outstanding of Rs 3,212.17 crore as of September 30, 2025.</p><p>Furthermore, the bank will auction its written-off loan portfolio worth Rs 3,719.14 crore.</p><p>The portfolios include loans from the Emerging Entrepreneurs Business (EEB) segment, covering group loans and small business and agricultural loans, as well as the Aspiring Business Group (ABG). The sale will be conducted through Asset Reconstruction Companies (ARCs) and other permitted transferees.</p><p><h2>What is an NPA?</h2>For readers who are unaware, an NPA stands for Non-Performing Asset. It is a loan or advance where the borrower has stopped paying interest or principal for a specified period.</p><p>An NPA also indicates potential losses for the company and is considered a key measure of asset quality.</p><p><h2>Bandhan Bank Limited Share Performance</h2>The company’s share price concluded the day on a high note, settling 0.4 per cent higher, up Rs 0.65 at Rs 150.30.</p><p>However, in terms of returns, the share has not performed well, declining nearly 60 per cent over the past five years. A similar trend is seen over the 1, 2, and 3-year periods as well.</p><p><h2>About Bandhan Bank Limited</h2>Bandhan Bank is a private sector bank and is a component of the BSE 500. It has a market capitalisation of Rs 24,212.90 crore.</p><p><strong><em>(Disclaimer: The above article is meant for informational purposes only, and should not be considered as any investment advice. ET NOW DIGITAL suggests its readers/audience to consult their financial advisors before making any money-related decisions.)</p><p></em></strong><em></p><p></em></p>'}],
#  'authors': [{'name': 'Daksh Grover'}],
#  'author': 'Daksh Grover',
#  'author_detail': {'name': 'Daksh Grover'}}

# %%
def fetch_rss_feeds():
    articles = []
    for feed in RSS_FEEDS:
        parsed = feedparser.parse(feed)
        for entry in parsed.entries:
            articles.append({
                "source": feed,
                "url": entry.link,
                "title": entry.title,
                "content": entry.summary,
                "published_at": getattr(entry, "published", None)
            })
    print("Fetching News was successful!")
    return articles

articles = fetch_rss_feeds()
print(f"---\nTotal articles fetched: {len(articles)}")
articles[23]
# Out:
# Fetching News was successful!
# ---
# Total articles fetched: 400
# {'source': 'https://www.marketbeat.com/feed/',
#  'url': 'https://www.marketbeat.com/originals/from-science-project-to-solvent-werides-761-revenue-surge/',
#  'title': 'From Science Project to Solvent: WeRide’s 761% Revenue Surge',
#  'content': 'WeRide stock rallied significantly as the company reported a massive surge in robotaxi revenue and successfully expanded its operations in the Middle East.',
#  'published_at': 'Tue, 25 Nov 2025 16:48:00 GMT'}

# %%
def clean_text(text):
    text = re.sub(r"\s+", " ", text)
    text = text.strip()
    return text

def standardize_article(a):
    return {
        "source": a["source"],
        "url": a["url"],
        "title": clean_text(a["title"]),
        "content": clean_text(a["content"]),
        "published_at": a["published_at"]
    }

standardized_articles = [standardize_article(a) for a in articles]
print("All articles have been standardized")
standardized_articles[23]
# Out:
# All articles have been standardized
# {'source': 'https://www.marketbeat.com/feed/',
#  'url': 'https://www.marketbeat.com/originals/from-science-project-to-solvent-werides-761-revenue-surge/',
#  'title': 'From Science Project to Solvent: WeRide’s 761% Revenue Surge',
#  'content': 'WeRide stock rallied significantly as the company reported a massive surge in robotaxi revenue and successfully expanded its operations in the Middle East.',
#  'published_at': 'Tue, 25 Nov 2025 16:48:00 GMT'}

# %%
os.makedirs("../data", exist_ok=True)

conn = sqlite3.connect("../data/financial_news.db")
print("Connected!")

cur = conn.cursor()
cur.execute("""
CREATE TABLE IF NOT EXISTS raw_news (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            source TEXT,
            url TEXT,
            title TEXT,
            content TEXT,
            published_at TEXT
            )
""")

conn.commit()
cur.close()
conn.close()
# Out:
# Connected!

# %%
def save_articles_to_db(article):
    conn = sqlite3.connect("../data/financial_news.db")
    cur = conn.cursor()

    cur.execute("""
        INSERT INTO raw_news (source, url, title, content, published_at)
        VALUES ( ?, ?, ?, ?, ?)
        """, (
            article["source"],
            article["url"],
            article["title"],
            article["content"],
            article["published_at"]
        ))
    
    conn.commit()
    cur.close()
    conn.close()

for article in standardized_articles:
    save_articles_to_db(article)

print("All articles saved to db.")
# Out:
# All articles saved to db.
