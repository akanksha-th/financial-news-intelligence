# %%
# https://huggingface.co/TheBloke/phi-2-GGUF/blob/main/phi-2.Q4_0.gguf

# %%
from gpt4all import GPT4All

model = GPT4All(model_path="C:/Users/aktkr/financial-news-intelligence/models/phi-2.Q4_0.gguf", model_name=None, allow_download=False)
response = model.generate("Rewrite this query: impact of RBI policy")
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 from gpt4all import GPT4All
# ----> 3 model = GPT4All(model_path="C:/Users/aktkr/financial-news-intelligence/models/phi-2.Q4_0.gguf", model_name=None, allow_download=False)
#       4 response = model.generate("Rewrite this query: impact of RBI policy")
#       5 print(response)
#
# File c:\Users\aktkr\financial-news-intelligence\.multi_agent_langgraph\Lib\site-packages\gpt4all\gpt4all.py:235, in GPT4All.__init__(self, model_name, model_path, model_type, allow_download, n_threads, device, n_ctx, ngl, verbose)
#     232         device_init = _remove_prefix(device, "kompute:")
#     234 # Retrieve model and download if allowed
# --> 235 self.config: ConfigType = self.retrieve_model(model_name, model_path=model_path, allow_download=allow_download, verbose=verbose)
# ...
